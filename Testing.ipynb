# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
t = np.arange(0.0, 5.0, 0.1)
x = 1 + np.sin(2 * np.pi * t)

_, ax = plt.subplots()
ax.plot(t, x)
